# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from gaf.gaf import GAF
from ts2vg import NaturalVG, HorizontalVG
from utils.draw import draw_side_by_side

# %%
xs = [0.71, 0.53, 0.58, 0.29, 0.3, 0.77, 0.01, 0.76, 0.81, 0.71, 0.05, 0.41, 0.86, 0.79, 0.96, 0.87, 0.06, 0.95, 0.38]
xs = np.array(xs)

# %%
xs
# Out:
# array([0.71, 0.53, 0.58, 0.29, 0.3 , 0.77, 0.01, 0.76, 0.81, 0.71, 0.05,
#        0.41, 0.86, 0.79, 0.96, 0.87, 0.06, 0.95, 0.38])

# %%
plt.bar(np.arange(len(xs)), xs)
plt.yticks(np.arange(0, 1, 0.1))
plt.show()

# %%
from gaf.gaf import GAF
g = GAF(xs, threshold=0)
gs = g.gasf()
gd = g.gadf()

# %%
plt.bar(np.arange(len(xs)), g.angles.reshape(-1))
plt.yticks(np.arange(0, 1, 0.1))
plt.show()

# %%
aux = 
plt.imshow()
plt.show()

# %%
[xs[i] for i, x in enumerate(g.angles) if x < np.pi/8]
# Out:
# [0.71, 0.53, 0.58, 0.77, 0.76, 0.81, 0.71, 0.86, 0.79, 0.96, 0.87, 0.95]

# %%
draw_side_by_side(xs, np.arange(len(xs)), gs, gd)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler =MinMaxScaler(feature_range=(-1, 1))

# %%
sx = scaler.fit_transform(xs.reshape(-1, 1))

# %%
g1 = GAF(sx)
gss = g1.gasf()
gsd = g1.gadf()
draw_side_by_side(sx, np.arange(len(xs)), gss, gsd)

# %%
from pyts.image import GramianAngularField

# %%
ga = GramianAngularField(method="summation")
Xs = ga.fit_transform(xs.reshape(-1, 1))

# %%
xs
# Out:
# array([0.71, 0.53, 0.58, 0.29, 0.3 , 0.77, 0.01, 0.76, 0.81, 0.71, 0.05,
#        0.41, 0.86, 0.79, 0.96, 0.87, 0.06, 0.95, 0.38])
