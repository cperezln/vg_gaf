# %%
from gadf import gadf
from gasf import gasf
from vg import vg
from hvg import hvg
from network_utils import white_noise, plot_hist
from random import gauss
import pandas
from pandas import Series
import numpy as np
from collections import Counter
import math

# %%
def extraer_diagonales(matriz):
    nueva_matriz = [[0] * len(matriz) for _ in range(len(matriz))]

    nueva_matriz[0][0] = matriz[0][0]
    nueva_matriz[0][1] = matriz[0][1]
    nueva_matriz[len(matriz)-1][len(matriz)-1] = matriz[len(matriz)-1][len(matriz)-1]
    nueva_matriz[len(matriz)-1][len(matriz)-2] = matriz[len(matriz)-1][len(matriz)-2]

    # Copiar elementos de la diagonal superior
    for i in range(filas):
        for j in range(i + 1, columnas):
            nueva_matriz[i][j] = matriz[i][j]

    # Copiar elementos de la diagonal inferior
    for i in range(1, filas):
        for j in range(i):
            nueva_matriz[i][j] = matriz[i][j]

    return nueva_matriz

# %%
# Ejemplo de uso:
matriz_ejemplo = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

nueva_matriz = extraer_diagonales(matriz_ejemplo)
print(nueva_matriz)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# # Experimento 1

# %%
t_d, ts = plot_hist(10, 400)

# %% [markdown]
# Con lo anterior vemos que en este experimento la distribución de el grado de los grafos sigue $P(k) = k^{-\alpha}$ para un cierto $\alpha.$

# %%
ts = white_noise(25)

# %%
gadm = gadf(ts)
# Out:
# /home/cperezln/vg-gaf/vg_gaf/cristianperez/gadf.py:6: RuntimeWarning: invalid value encountered in arccos
#   angles = [np.arccos(i) for i in rescaled]

# %%
gasm = gasf(ts)
# Out:
# /home/cperezln/vg-gaf/vg_gaf/cristianperez/gasf.py:6: RuntimeWarning: invalid value encountered in arccos
#   angles = [np.arccos(i) for i in rescaled]

# %%
vg = vg(ts)[1]

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(gadm, cmap='gray')
plt.colorbar();

# %%
plt.imshow(gasm, cmap = 'gray')

# %%
plt.imshow(vg, cmap='gray')
plt.colorbar();

# %% [markdown]
# # Experimento 2

# %%
t_d, g, ts = plot_hist(5, 50)

# %%
from networkx import sigma

# %%
sigma(g[0][0])
# Out:
# 2.5669331132264537

# %%
sigma(g[1][0])
# Out:
# 3.445434279344937

# %%
from networkx import omega

# %%
omega(g[0][0])
# Out:
# -0.09854160709179283

# %%
omega(g[1][0])
# Out:
# -0.14453271028037384

# %% [markdown]
# # Nuevos experimentos

# %% [markdown]
# - GAF como grafo, ¿qué propiedades tiene? ¿cuánto se parece al GAF? (en cuanto a propiedades teóricas de grafos)
# - GAF pero con vecinos cercanos, i.e, calcular para diagonales.
# - VG de ruido blanco y VG de serie normal. ¿Qué propiedades del rudio blanco de la serie puedes obtener a partir de conocer las propiedades del VG de ruido blanco?

# %% [markdown]
# ## Experimento 1
# Vamos a estudiar el parecido de la escalarización de las diagonales principales (superiores) del GAF y VG

# %%
ts = white_noise(50)

# %%
vgm = vg(ts)[1]

# %%
gasm = gasf(ts)

# %%
gadm = gadf(ts)

# %%
diag_gaf = [gasm[i][i+1] for i in range(49)]

# %%
diag_vg = [vgm[i][i+1] for i in range(49)]

# %%
diag_dgaf = [gadm[i][i+1] for i in range(49)]

# %%
import numpy as np

def NormalizeData(data):
    return (data - np.min(data)) / (np.max(data) - np.min(data))

# %%
ndiag_gaf = NormalizeData(diag_gaf)

# %%
ndiag_dgaf = NormalizeData(diag_dgaf)

# %%
ndiag_vg = NormalizeData(diag_vg)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(range(49), ndiag_gaf)

# %%
fig, ax = plt.subplots()
ax.plot(range(49), ndiag_vg)

# %%
fig, ax = plt.subplots()
ax.plot(range(49), ndiag_dgaf)

# %%
from scipy.stats import pearsonr, spearmanr
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
spearmanr(ndiag_gaf, ndiag_dgaf)
# Out:
# SpearmanrResult(correlation=-0.0323469387755102, pvalue=0.8253720328960662)

# %%
spearmanr(ndiag_gaf, ndiag_vg)
# Out:
# SpearmanrResult(correlation=0.04571428571428571, pvalue=0.7551148352966082)

# %%
spearmanr(ndiag_dgaf, ndiag_vg)
# Out:
# SpearmanrResult(correlation=-0.994081632653061, pvalue=5.711594851736317e-47)

# %% [markdown]
# Para la primera muestra parece que el experimento tendría más sentido con el Gramian Angular Field de diferencias que con el de sumas. Vamos a computarlo para 1000 muestras distintas de esta forma.

# %%
ts_1000 = [white_noise(50) for _ in range(1000)]

# %%
ndiag_gaf_1000 = [NormalizeData([gasf(ts_1000[j])[i][i+1] for i in range(49)]) for j in range(1000)]
# Out:
# /home/cperezln/vg-gaf/vg_gaf/cristianperez/gasf.py:6: RuntimeWarning: invalid value encountered in arccos
#   angles = [np.arccos(i) for i in rescaled]

# %%
ndiag_dgaf_1000 = [NormalizeData([gadf(ts_1000[j])[i][i+1] for i in range(49)]) for j in range(1000)]
# Out:
# /home/cperezln/vg-gaf/vg_gaf/cristianperez/gadf.py:6: RuntimeWarning: invalid value encountered in arccos
#   angles = [np.arccos(i) for i in rescaled]

# %%
ndiag_vg_1000 = [NormalizeData([(vg(ts_1000[j])[1])[i][i+1] for i in range(49)]) for j in range(1000)]

# %% [markdown]
# Una vez se tienen los valores para las 1000 muestras, vamos a calcular el coeficiente de Spearman para todas las combinaciones para todas las muestras

# %%
sgg = [spearmanr(i, j) for i, j in zip(ndiag_gaf_1000, ndiag_dgaf_1000)]
sgv = [spearmanr(i, j) for i, j in zip(ndiag_gaf_1000, ndiag_vg_1000)]
svg = [spearmanr(i, j) for i, j in zip(ndiag_dgaf_1000, ndiag_vg_1000)]

# %%
import numpy as np

# %%
sggf = [i[0] for i in sgg]
sgvf = [i[0] for i in sgv]
svgf = [i[0] for i in svg]

# %%
np.mean(np.array(sggf)[~np.isnan(sggf)])
# Out:
# -0.0023926882365062404

# %%
np.mean(np.array(sgvf)[~np.isnan(sgvf)])
# Out:
# 0.0038347794207503356

# %%
np.mean(np.array(svgf)[~np.isnan(svgf)])
# Out:
# -0.9892906897359109

# %%
diag_gaf_1000 = [[gasf(ts_1000[j])[i][i+1] for i in range(49)] for j in range(1000)]
diag_dgaf_1000 = [[gadf(ts_1000[j])[i][i+1] for i in range(49)] for j in range(1000)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_22893/1025002672.py in <module>
#       1 diag_gaf_1000 = [[gasf(ts_1000[j])[i][i+1] for i in range(49)] for j in range(1000)]
#       2 diag_dgaf_1000 = [[gadf(ts_1000[j])[i][i+1] for i in range(49)] for j in range(1000)]
# ----> 3 diag_vg_1000 = [[vg(ts_1000[j])[i][i+1] for i in range(49)] for j in range(1000)]
#
# /tmp/ipykernel_22893/1025002672.py in <listcomp>(.0)
#       1 diag_gaf_1000 = [[gasf(ts_1000[j])[i][i+1] for i in range(49)] for j in range(1000)]
#       2 diag_dgaf_1000 = [[gadf(ts_1000[j])[i][i+1] for i in range(49)] for j in range(1000)]
# ----> 3 diag_vg_1000 = [[vg(ts_1000[j])[i][i+1] for i in range(49)] for j in range(1000)]
#
# /tmp/ipykernel_22893/1025002672.py in <listcomp>(.0)
#       1 diag_gaf_1000 = [[gasf(ts_1000[j])[i][i+1] for i in range(49)] for j in range(1000)]
#       2 diag_dgaf_1000 = [[gadf(ts_1000[j])[i][i+1] for i in range(49)] for j in range(1000)]
# ----> 3 diag_vg_1000 = [[vg(ts_1000[j])[i][i+1] for i in range(49)] for j in range(1000)]
#
# TypeError: 'Graph' object is not callable

# %%
diag_vg_1000 = [[vg(ts_1000[j])[1][i][i+1] for i in range(49)] for j in range(1000)]

# %%
nnsgg = [spearmanr(i, j) for i, j in zip(diag_gaf_1000, diag_dgaf_1000)]
nnsgv = [spearmanr(i, j) for i, j in zip(diag_gaf_1000, diag_vg_1000)]
nnsvg = [spearmanr(i, j) for i, j in zip(diag_dgaf_1000, diag_vg_1000)]

# %%
nnsggf = [i[0] for i in nnsgg]
nnsgvf = [i[0] for i in nnsgv]
nnsvgf = [i[0] for i in nnsvg]

# %%
np.mean(np.array(nnsggf)[~np.isnan(nnsggf)])
# Out:
# -0.002394643269579578

# %%
np.mean(np.array(nnsgvf)[~np.isnan(nnsgvf)])
# Out:
# 0.0038347794207503356

# %%
np.mean(np.array(nnsvgf)[~np.isnan(nnsvgf)])
# Out:
# -0.9892927068229117

# %% [markdown]
# ### Parte 2, comparación de matrices y grafos

# %% [markdown]
# Parece que en la vecindad, la GADF y VG se parecen bastante... ¿Se puede seguir explotando esto?

# %%
ts = white_noise(25)

# %%
vg1 = vg(ts)[1]

# %%
gadm1 = gadf(ts)

# %%
vg1n = NormalizeData(vg1)

# %%
gadm1n = NormalizeData(gadm1)

# %%
import networkx as nx

# %%
vg = nx.Graph(np.array(vg1n))

# %%
gadg = nx.Graph(np.array(gadm1n))

# %%
nx.draw(vg)

# %%
nx.draw(gadg)

# %%
nx.graph_edit_distance(vg, gadg)
# Out:
# 0.0

# %%
vg_s = nx.Graph(np.array(vg1))

# %%
gadg_s = nx.Graph(np.array(gadm1))

# %%
nx.draw(vg_s)

# %%
nx.draw(gadg_s)

# %%
nx.graph_edit_distance(vg_s, gadg_s)
# Out:
# 242.0

# %% [markdown]
# Vamos ahora a verlo con imágenes
# ### Normalizadas

# %%
plt.imshow(vg1n, cmap='gray')
plt.colorbar();

# %%
plt.imshow(gadm1n, cmap='gray')
plt.colorbar();

# %% [markdown]
# ### No normalizadas

# %%
plt.imshow(vg1, cmap='gray')
plt.colorbar();

# %%
plt.imshow(gadm1, cmap='gray')
plt.colorbar();

# %% [markdown]
# Uno de los problemas que encuentro principales de intentar comparar el VG con el GAF es lo sparse que es el VG y lo denso que es el otro. Vamos a probar a quedarnos unicameente con una parte de la matriz

# %% [markdown]
# # Experimento 2
# Parecidos entre los grafos que vienen de la matriz de GAF y VG

# %%
ts = white_noise(25)

# %%
gaf = np.array(gasf(ts)) + 1

# %%
gaf
# Out:
# array([[ 1.98574588,  1.412852  ,  0.96485737,  1.81887466,  1.91351366,
#          0.53174231,  1.65617311,  0.89574334,  0.77016055,  1.03187951,
#          2.49287294,  1.92917171,  1.24310187,  0.94961069,  1.9537889 ,
#          2.40188907,  2.15954178,  1.57264693,  2.05134911,  0.50716754,
#                 nan,  2.22524482,  0.91136322,  1.82135849,  1.56737553],
#        [ 1.412852  ,  0.83995812,  0.39196349,  1.24598079,  1.34061979,
#         -0.04115157,  1.08327924,  0.32284946,  0.19726667,  0.45898563,
#          1.91997906,  1.35627783,  0.670208  ,  0.37671682,  1.38089503,
#          1.8289952 ,  1.58664791,  0.99975305,  1.47845523, -0.06572634,
#                 nan,  1.65235094,  0.33846935,  1.24846462,  0.99448166],
#        [ 0.96485737,  0.39196349, -0.05603115,  0.79798615,  0.89262515,
#         -0.4891462 ,  0.6352846 , -0.12514518, -0.25072796,  0.010991  ,
#          1.47198443,  0.9082832 ,  0.22221336, -0.07127782,  0.93290039,
#          1.38100056,  1.13865327,  0.55175842,  1.03046059, -0.51372097,
#                 nan,  1.2043563 , -0.10952529,  0.80046998,  0.54648702],
#        [ 1.81887466,  1.24598079,  0.79798615,  1.65200345,  1.74664245,
#          0.36487109,  1.4893019 ,  0.72887212,  0.60328933,  0.86500829,
#          2.32600172,  1.76230049,  1.07623066,  0.78273948,  1.78691769,
#          2.23501786,  1.99267057,  1.40577572,  1.88447789,  0.34029632,
#                 nan,  2.0583736 ,  0.74449201,  1.65448728,  1.40050432],
#        [ 1.91351366,  1.34061979,  0.89262515,  1.74664245,  1.84128145,
#          0.45951009,  1.5839409 ,  0.82351112,  0.69792833,  0.9596473 ,
#          2.42064072,  1.85693949,  1.17086966,  0.87737848,  1.88155669,
#          2.32965686,  2.08730957,  1.50041472,  1.97911689,  0.43493532,
#                 nan,  2.1530126 ,  0.83913101,  1.74912628,  1.49514332],
#        [ 0.53174231, -0.04115157, -0.4891462 ,  0.36487109,  0.45951009,
#         -0.92226126,  0.20216954, -0.55826023, -0.68384302, -0.42212406,
#          1.03886937,  0.47516814, -0.2109017 , -0.50439288,  0.49978533,
#          0.9478855 ,  0.70553821,  0.11864336,  0.59734554, -0.94683603,
#                 nan,  0.77124125, -0.54264035,  0.36735492,  0.11337196],
#        [ 1.65617311,  1.08327924,  0.6352846 ,  1.4893019 ,  1.5839409 ,
#          0.20216954,  1.32660035,  0.56617057,  0.44058778,  0.70230675,
#          2.16330017,  1.59959894,  0.91352911,  0.62003793,  1.62421614,
#          2.07231631,  1.82996902,  1.24307417,  1.72177634,  0.17759477,
#                 nan,  1.89567205,  0.58179046,  1.49178573,  1.23780277],
#        [ 0.89574334,  0.32284946, -0.12514518,  0.72887212,  0.82351112,
#         -0.55826023,  0.56617057, -0.1942592 , -0.31984199, -0.05812303,
#          1.4028704 ,  0.83916917,  0.15309933, -0.14039185,  0.86378636,
#          1.31188653,  1.06953924,  0.48264439,  0.96134657, -0.582835  ,
#                 nan,  1.13524228, -0.17863932,  0.73135595,  0.47737299],
#        [ 0.77016055,  0.19726667, -0.25072796,  0.60328933,  0.69792833,
#         -0.68384302,  0.44058778, -0.31984199, -0.44542478, -0.18370582,
#          1.27728761,  0.71358638,  0.02751655, -0.26597464,  0.73820357,
#          1.18630374,  0.94395645,  0.3570616 ,  0.83576378, -0.70841779,
#                 nan,  1.00965949, -0.30422211,  0.60577316,  0.3517902 ],
#        [ 1.03187951,  0.45898563,  0.010991  ,  0.86500829,  0.9596473 ,
#         -0.42212406,  0.70230675, -0.05812303, -0.18370582,  0.07801314,
#          1.53900657,  0.97530534,  0.28923551, -0.00425567,  0.99992254,
#          1.4480227 ,  1.20567542,  0.61878056,  1.09748274, -0.44669883,
#                 nan,  1.27137845, -0.04250314,  0.86749212,  0.61350917],
#        [ 2.49287294,  1.91997906,  1.47198443,  2.32600172,  2.42064072,
#          1.03886937,  2.16330017,  1.4028704 ,  1.27728761,  1.53900657,
#          3.        ,  2.43629877,  1.75022894,  1.45673775,  2.46091596,
#          2.90901613,  2.66666884,  2.07977399,  2.55847617,  1.0142946 ,
#                 nan,  2.73237188,  1.41849029,  2.32848555,  2.07450259],
#        [ 1.92917171,  1.35627783,  0.9082832 ,  1.76230049,  1.85693949,
#          0.47516814,  1.59959894,  0.83916917,  0.71358638,  0.97530534,
#          2.43629877,  1.87259754,  1.18652771,  0.89303652,  1.89721473,
#          2.3453149 ,  2.10296761,  1.51607276,  1.99477494,  0.45059337,
#                 nan,  2.16867065,  0.85478906,  1.76478432,  1.51080136],
#        [ 1.24310187,  0.670208  ,  0.22221336,  1.07623066,  1.17086966,
#         -0.2109017 ,  0.91352911,  0.15309933,  0.02751655,  0.28923551,
#          1.75022894,  1.18652771,  0.50045787,  0.20696669,  1.2111449 ,
#          1.65924507,  1.41689778,  0.83000293,  1.3087051 , -0.23547647,
#                 nan,  1.48260081,  0.16871922,  1.07871449,  0.82473153],
#        [ 0.94961069,  0.37671682, -0.07127782,  0.78273948,  0.87737848,
#         -0.50439288,  0.62003793, -0.14039185, -0.26597464, -0.00425567,
#          1.45673775,  0.89303652,  0.20696669, -0.08652449,  0.91765372,
#          1.36575389,  1.1234066 ,  0.53651175,  1.01521392, -0.52896765,
#                 nan,  1.18910963, -0.12477196,  0.78522331,  0.53124035],
#        [ 1.9537889 ,  1.38089503,  0.93290039,  1.78691769,  1.88155669,
#          0.49978533,  1.62421614,  0.86378636,  0.73820357,  0.99992254,
#          2.46091596,  1.89721473,  1.2111449 ,  0.91765372,  1.92183193,
#          2.3699321 ,  2.12758481,  1.54068996,  2.01939213,  0.47521056,
#                 nan,  2.19328784,  0.87940625,  1.78940152,  1.53541856],
#        [ 2.40188907,  1.8289952 ,  1.38100056,  2.23501786,  2.32965686,
#          0.9478855 ,  2.07231631,  1.31188653,  1.18630374,  1.4480227 ,
#          2.90901613,  2.3453149 ,  1.65924507,  1.36575389,  2.3699321 ,
#          2.81803227,  2.57568498,  1.98879013,  2.4674923 ,  0.92331073,
#                 nan,  2.64138801,  1.32750642,  2.23750169,  1.98351873],
#        [ 2.15954178,  1.58664791,  1.13865327,  1.99267057,  2.08730957,
#          0.70553821,  1.82996902,  1.06953924,  0.94395645,  1.20567542,
#          2.66666884,  2.10296761,  1.41689778,  1.1234066 ,  2.12758481,
#          2.57568498,  2.33333769,  1.74644284,  2.22514501,  0.68096344,
#                 nan,  2.39904072,  1.08515913,  1.9951544 ,  1.74117144],
#        [ 1.57264693,  0.99975305,  0.55175842,  1.40577572,  1.50041472,
#          0.11864336,  1.24307417,  0.48264439,  0.3570616 ,  0.61878056,
#          2.07977399,  1.51607276,  0.83000293,  0.53651175,  1.54068996,
#          1.98879013,  1.74644284,  1.15954798,  1.63825016,  0.09406859,
#                 nan,  1.81214587,  0.49826428,  1.40825955,  1.15427659],
#        [ 2.05134911,  1.47845523,  1.03046059,  1.88447789,  1.97911689,
#          0.59734554,  1.72177634,  0.96134657,  0.83576378,  1.09748274,
#          2.55847617,  1.99477494,  1.3087051 ,  1.01521392,  2.01939213,
#          2.4674923 ,  2.22514501,  1.63825016,  2.11695233,  0.57277077,
#                 nan,  2.29084805,  0.97696645,  1.88696172,  1.63297876],
#        [ 0.50716754, -0.06572634, -0.51372097,  0.34029632,  0.43493532,
#         -0.94683603,  0.17759477, -0.582835  , -0.70841779, -0.44669883,
#          1.0142946 ,  0.45059337, -0.23547647, -0.52896765,  0.47521056,
#          0.92331073,  0.68096344,  0.09406859,  0.57277077, -0.9714108 ,
#                 nan,  0.74666648, -0.56721512,  0.34278015,  0.08879719],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan],
#        [ 2.22524482,  1.65235094,  1.2043563 ,  2.0583736 ,  2.1530126 ,
#          0.77124125,  1.89567205,  1.13524228,  1.00965949,  1.27137845,
#          2.73237188,  2.16867065,  1.48260081,  1.18910963,  2.19328784,
#          2.64138801,  2.39904072,  1.81214587,  2.29084805,  0.74666648,
#                 nan,  2.46474376,  1.15086216,  2.06085743,  1.80687447],
#        [ 0.91136322,  0.33846935, -0.10952529,  0.74449201,  0.83913101,
#         -0.54264035,  0.58179046, -0.17863932, -0.30422211, -0.04250314,
#          1.41849029,  0.85478906,  0.16871922, -0.12477196,  0.87940625,
#          1.32750642,  1.08515913,  0.49826428,  0.97696645, -0.56721512,
#                 nan,  1.15086216, -0.16301943,  0.74697584,  0.49299288],
#        [ 1.82135849,  1.24846462,  0.80046998,  1.65448728,  1.74912628,
#          0.36735492,  1.49178573,  0.73135595,  0.60577316,  0.86749212,
#          2.32848555,  1.76478432,  1.07871449,  0.78522331,  1.78940152,
#          2.23750169,  1.9951544 ,  1.40825955,  1.88696172,  0.34278015,
#                 nan,  2.06085743,  0.74697584,  1.65697111,  1.40298815],
#        [ 1.56737553,  0.99448166,  0.54648702,  1.40050432,  1.49514332,
#          0.11337196,  1.23780277,  0.47737299,  0.3517902 ,  0.61350917,
#          2.07450259,  1.51080136,  0.82473153,  0.53124035,  1.53541856,
#          1.98351873,  1.74117144,  1.15427659,  1.63297876,  0.08879719,
#                 nan,  1.80687447,  0.49299288,  1.40298815,  1.14900519]])
