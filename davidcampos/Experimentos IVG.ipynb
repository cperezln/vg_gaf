# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import ivg

# %%
boat = Image.open('boat128.png').convert("L")
ivg.compare(boat,0.33)

# %%
baboon = Image.open('baboon128.png').convert("L")
ivg.compare(baboon,0.33)

# %%
peppers = Image.open('peppers128.png').convert("L")
ivg.compare(peppers,0.33)

# %%
lena = Image.open('lena128.png').convert("L")
ivg.compare(lena,0.33)
